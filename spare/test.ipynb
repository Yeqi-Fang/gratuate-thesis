# %%
import numpy as np

# read /mnt/d/fyq/sinogram/reconstruction_npy_full_train/2000000000/listmode/listmode_data_minimal_0_2000000000.npz

data = np.load('/mnt/d/fyq/sinogram/reconstruction_npy_full_train/2000000000/sinogram/reconstructed_index0_num2000000000.npy')

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(2, 1, figsize=(7, 7))
axs[0].imshow(data[:, :, 10], cmap='magma')
axs[1].imshow(data[:, :, 10 + 1], cmap='magma')
# plt.imshow(data[:, :, 10], cmap='viridis')
plt.show()

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(2, 1, figsize=(7, 7))
axs[0].imshow(data[:, :, 30], cmap='magma')
axs[1].imshow(data[:, :, 30 + 42], cmap='magma')
# plt.imshow(data[:, :, 10], cmap='viridis')
plt.show()
